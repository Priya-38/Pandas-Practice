# %% [markdown]
# **PANDAS LIBRARAY**
#
# It is used for data processing and analysis.
#
# Pandas Dataframe:
#
# It is a two dimensional(2-D) data structure with rows and columns.

# %%
#importing the pandaqs library:
import pandas as pd
import pandas as np

# %% [markdown]
# Creating a Pandas Dataframe:

# %%
#importing the boston house price data:
from sklearn.datasets import load_boston

# %%
boston_df = load_boston()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
type(boston_df)
# Out:
# sklearn.utils.Bunch

# %%
print(boston_df)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
boston_dataset = pd.DataFrame(boston_df.data, columns = boston_df.feature_names)
#checking the first five rows:
boston_dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
#checking the last five rows:
boston_dataset.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 501  0.06263  0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  391.99   9.67
# 502  0.04527  0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   9.08
# 503  0.06076  0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   5.64
# 504  0.10959  0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  393.45   6.48
# 505  0.04741  0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   7.88
#
# [5 rows x 13 columns]

# %%
#checking the number of rows and columns:
boston_dataset.shape
# Out:
# (506, 13)

# %%
type(boston_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
#loading a csv file to pandas dataframe:
df = pd.read_csv('/content/drive/MyDrive/heart (1).csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [5 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (303, 14)

# %%
#checking the datatype of the each of the columns:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#getting the statistical measure about the dataset:
df.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.value_counts('target')
# Out:
# target
# 1    165
# 0    138
# dtype: int64

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp  ...     slope        ca      thal
# target                                 ...
# 0       56.601449  0.826087  0.478261  ...  1.166667  1.166667  2.543478
# 1       52.496970  0.563636  1.375758  ...  1.593939  0.363636  2.121212
#
# [2 rows x 13 columns]

# %%
#checking the number of counts of each columns:
df.count()
# Out:
# age         303
# sex         303
# cp          303
# trestbps    303
# chol        303
# fbs         303
# restecg     303
# thalach     303
# exang       303
# oldpeak     303
# slope       303
# ca          303
# thal        303
# target      303
# dtype: int64

# %%
df.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
df.std()
# Out:
# age          9.082101
# sex          0.466011
# cp           1.032052
# trestbps    17.538143
# chol        51.830751
# fbs          0.356198
# restecg      0.525860
# thalach     22.905161
# exang        0.469794
# oldpeak      1.161075
# slope        0.616226
# ca           1.022606
# thal         0.612277
# target       0.498835
# dtype: float64

# %%
df.min()
# Out:
# age          29.0
# sex           0.0
# cp            0.0
# trestbps     94.0
# chol        126.0
# fbs           0.0
# restecg       0.0
# thalach      71.0
# exang         0.0
# oldpeak       0.0
# slope         0.0
# ca            0.0
# thal          0.0
# target        0.0
# dtype: float64

# %%
df.max()
# Out:
# age          77.0
# sex           1.0
# cp            3.0
# trestbps    200.0
# chol        564.0
# fbs           1.0
# restecg       2.0
# thalach     202.0
# exang         1.0
# oldpeak       6.2
# slope         2.0
# ca            4.0
# thal          3.0
# target        1.0
# dtype: float64

# %%
df.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
#adding a column to a pandas dataframe:
boston_dataset['Price'] = boston_df.target

# %%
boston_dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  Price
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
#
# [5 rows x 14 columns]

# %%
#removing a row from a dataset:
boston_dataset.drop(index=0, axis = 0)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  Price
# 1    0.02731  0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2    0.02729  0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3    0.03237  0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4    0.06905  0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
# 5    0.02985  0.0   2.18   0.0  0.458  ...  222.0     18.7  394.12   5.21   28.7
# ..       ...  ...    ...   ...    ...  ...    ...      ...     ...    ...    ...
# 501  0.06263  0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67   22.4
# 502  0.04527  0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08   20.6
# 503  0.06076  0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64   23.9
# 504  0.10959  0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48   22.0
# 505  0.04741  0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   7.88   11.9
#
# ...

# %%
#removing a column from a dataset:
boston_dataset.drop(columns = 'Price', axis = 1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...  ...  ...    ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  391.99   9.67
# 502  0.04527   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   5.64
# 504  0.10959   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  393.45   6.48
# 505  0.04741   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   7.88
#
# ...

# %%
#locating a row in the dataset:
boston_dataset.iloc[2]
# Out:
# CRIM         0.02729
# ZN           0.00000
# INDUS        7.07000
# CHAS         0.00000
# NOX          0.46900
# RM           7.18500
# AGE         61.10000
# DIS          4.96710
# RAD          2.00000
# TAX        242.00000
# PTRATIO     17.80000
# B          392.83000
# LSTAT        4.03000
# Price       34.70000
# Name: 2, dtype: float64

# %%
#locating a column in the dataset:
boston_dataset.iloc[:,0] #first column
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
boston_dataset.iloc[:,10] #second column
# Out:
# 0      15.3
# 1      17.8
# 2      17.8
# 3      18.7
# 4      18.7
#        ...
# 501    21.0
# 502    21.0
# 503    21.0
# 504    21.0
# 505    21.0
# Name: PTRATIO, Length: 506, dtype: float64
